# %% [markdown]
# <a href="https://colab.research.google.com/github/jennifersolis-star/class-167/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-7togcudu
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-7togcudu
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=84f28bccf4d67a92dd8fb77ef4898db0b14ffb92a7cbc2965182138379cf795c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6322p7_4/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


import torch.nn as nn

model = nn.Sequential(
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),

    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),

    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),

    nn.Flatten(),

    nn.Linear(60, 100),
    nn.ReLU(),

    nn.Linear(100, 10)
)



# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
nn.Flatten(),
nn.Linear(40, 100),
nn.ReLU(),
nn.Linear(100, 100),
nn.ReLU(),
nn.Linear(100, 10))

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.549774, train error 61.10,  val loss 1.645627, percent error 66.00
# Epoch     1, train loss 1.295513, train error 48.10,  val loss 1.435111, percent error 57.80
# Epoch     2, train loss 1.103294, train error 38.92,  val loss 1.329290, percent error 52.20
# Epoch     3, train loss 0.972268, train error 34.97,  val loss 1.262695, percent error 50.20
# Epoch     4, train loss 0.955118, train error 35.90,  val loss 1.253725, percent error 49.60
# Epoch     5, train loss 0.755262, train error 25.85,  val loss 1.144627, percent error 44.40
# Epoch     6, train loss 0.717940, train error 25.78,  val loss 1.157156, percent error 44.00
# Epoch     7, train loss 0.624462, train error 21.07,  val loss 1.148950, percent error 44.40
# Epoch     8, train loss 0.553708, train error 18.25,  val loss 1.112713, percent error 41.60
# Epoch     9, train loss 0.517014, train error 17.20,  val loss 1.121952, percent error 40.20
# Epoch    10, train loss 0.438844, train error 14.55,  val loss 1.122877, percent error 40.30
# Epoch    11, train loss 0.383027, train error 11.93,  val loss 1.156923, percent error 39.90
# Epoch    12, train loss 0.354649, train error 11.55,  val loss 1.146399, percent error 39.00
# Epoch    13, train loss 0.329631, train error 10.53,  val loss 1.152522, percent error 39.40
# Epoch    14, train loss 0.253345, train error 7.43,  val loss 1.171203, percent error 37.60
# Epoch    15, train loss 0.241459, train error 7.25,  val loss 1.223432, percent error 36.90
# Epoch    16, train loss 0.204061, train error 5.88,  val loss 1.222235, percent error 35.30
# Epoch    17, train loss 0.164957, train error 3.68,  val loss 1.204485, percent error 38.00
# Epoch    18, train loss 0.170291, train error 5.07,  val loss 1.291757, percent error 37.10
# Epoch    19, train loss 0.131125, train error 2.80,  val loss 1.299946, percent error 37.60
# Epoch    20, train loss 0.071746, train error 0.53,  val loss 1.255115, percent error 36.00
# Epoch    21, train loss 0.057847, train error 0.12,  val loss 1.260932, percent error 35.20
# Epoch    22, train loss 0.051252, train error 0.07,  val loss 1.277357, percent error 35.20
# Epoch    23, train loss 0.045728, train error 0.05,  val loss 1.305635, percent error 35.00
# Epoch    24, train loss 0.041583, train error 0.07,  val loss 1.304224, percent error 34.20
# Epoch    25, train loss 0.039256, train error 0.05,  val loss 1.334123, percent error 34.80
# Epoch    26, train loss 0.036687, train error 0.07,  val loss 1.351252, percent error 35.60
# Epoch    27, train loss 0.032953, train error 0.00,  val loss 1.350241, percent error 34.40
# Epoch    28, train loss 0.029829, train error 0.03,  val loss 1.378331, percent error 34.50
# Epoch    29, train loss 0.027874, train error 0.00,  val loss 1.391286, percent error 34.60
# Epoch    30, train loss 0.026853, train error 0.00,  val loss 1.390152, percent error 34.60
# Epoch    31, train loss 0.024522, train error 0.00,  val loss 1.398920, percent error 34.80
# Epoch    32, train loss 0.023017, train error 0.00,  val loss 1.423066, percent error 34.60
# Epoch    33, train loss 0.021658, train error 0.00,  val loss 1.434184, percent error 34.70
# Epoch    34, train loss 0.020669, train error 0.00,  val loss 1.447968, percent error 35.40
# Epoch    35, train loss 0.019671, train error 0.00,  val loss 1.459478, percent error 34.80
# Epoch    36, train loss 0.018591, train error 0.00,  val loss 1.462258, percent error 34.80
# Epoch    37, train loss 0.017868, train error 0.00,  val loss 1.477742, percent error 34.80
# Epoch    38, train loss 0.016930, train error 0.00,  val loss 1.489211, percent error 34.90
# Epoch    39, train loss 0.016268, train error 0.00,  val loss 1.503640, percent error 35.00
# Epoch    40, train loss 0.015535, train error 0.00,  val loss 1.501020, percent error 35.20
# Epoch    41, train loss 0.015238, train error 0.00,  val loss 1.505951, percent error 35.10
# Epoch    42, train loss 0.014901, train error 0.00,  val loss 1.506235, percent error 35.10
# Epoch    43, train loss 0.014705, train error 0.00,  val loss 1.513442, percent error 35.60
# Epoch    44, train loss 0.014349, train error 0.00,  val loss 1.520712, percent error 35.30
# Epoch    45, train loss 0.014044, train error 0.00,  val loss 1.522601, percent error 35.30
# Epoch    46, train loss 0.013764, train error 0.00,  val loss 1.525853, percent error 35.20
# Epoch    47, train loss 0.013497, train error 0.00,  val loss 1.531971, percent error 35.40
# Epoch    48, train loss 0.013248, train error 0.00,  val loss 1.535135, percent error 35.40
# Epoch    49, train loss 0.012996, train error 0.00,  val loss 1.537093, percent error 35.50
# Epoch    50, train loss 0.012818, train error 0.00,  val loss 1.542824, percent error 35.50
# Epoch    51, train loss 0.012562, train error 0.00,  val loss 1.548585, percent error 35.20
# Epoch    52, train loss 0.012334, train error 0.00,  val loss 1.550609, percent error 35.40
# Epoch    53, train loss 0.012166, train error 0.00,  val loss 1.556003, percent error 35.30
# Epoch    54, train loss 0.011949, train error 0.00,  val loss 1.557425, percent error 35.40
# Epoch    55, train loss 0.011708, train error 0.00,  val loss 1.562036, percent error 35.60
# Epoch    56, train loss 0.011529, train error 0.00,  val loss 1.568876, percent error 35.60
# Epoch    57, train loss 0.011326, train error 0.00,  val loss 1.567544, percent error 35.80
# Epoch    58, train loss 0.011205, train error 0.00,  val loss 1.572964, percent error 35.50
# Epoch    59, train loss 0.011032, train error 0.00,  val loss 1.576669, percent error 35.30
# Epoch    60, train loss 0.010871, train error 0.00,  val loss 1.578067, percent error 35.50
# Epoch    61, train loss 0.010793, train error 0.00,  val loss 1.579767, percent error 35.70
# Epoch    62, train loss 0.010702, train error 0.00,  val loss 1.582332, percent error 35.40
# Epoch    63, train loss 0.010620, train error 0.00,  val loss 1.585016, percent error 35.70
# Epoch    64, train loss 0.010536, train error 0.00,  val loss 1.585769, percent error 35.50
# Epoch    65, train loss 0.010458, train error 0.00,  val loss 1.587703, percent error 35.50
# Epoch    66, train loss 0.010379, train error 0.00,  val loss 1.588891, percent error 35.50
# Epoch    67, train loss 0.010297, train error 0.00,  val loss 1.590742, percent error 35.60
# Epoch    68, train loss 0.010230, train error 0.00,  val loss 1.592340, percent error 35.50
# Epoch    69, train loss 0.010151, train error 0.00,  val loss 1.593742, percent error 35.60
# Epoch    70, train loss 0.010077, train error 0.00,  val loss 1.595409, percent error 35.50
# Epoch    71, train loss 0.010002, train error 0.00,  val loss 1.597165, percent error 35.40
# Epoch    72, train loss 0.009935, train error 0.00,  val loss 1.597708, percent error 35.40
# Epoch    73, train loss 0.009867, train error 0.00,  val loss 1.599239, percent error 35.60
# Epoch    74, train loss 0.009794, train error 0.00,  val loss 1.601242, percent error 35.60
# Epoch    75, train loss 0.009740, train error 0.00,  val loss 1.603219, percent error 35.40
# Epoch    76, train loss 0.009648, train error 0.00,  val loss 1.605058, percent error 35.40
# Epoch    77, train loss 0.009585, train error 0.00,  val loss 1.606213, percent error 35.60
# Epoch    78, train loss 0.009516, train error 0.00,  val loss 1.607308, percent error 35.50
# Epoch    79, train loss 0.009445, train error 0.00,  val loss 1.609650, percent error 35.60
# Epoch    80, train loss 0.009410, train error 0.00,  val loss 1.610427, percent error 35.50
# Epoch    81, train loss 0.009377, train error 0.00,  val loss 1.611151, percent error 35.50
# Epoch    82, train loss 0.009344, train error 0.00,  val loss 1.612226, percent error 35.60
# Epoch    83, train loss 0.009311, train error 0.00,  val loss 1.612852, percent error 35.50
# Epoch    84, train loss 0.009280, train error 0.00,  val loss 1.613694, percent error 35.50
# Epoch    85, train loss 0.009248, train error 0.00,  val loss 1.614143, percent error 35.60
# Epoch    86, train loss 0.009217, train error 0.00,  val loss 1.615437, percent error 35.60
# Epoch    87, train loss 0.009187, train error 0.00,  val loss 1.615870, percent error 35.50
# Epoch    88, train loss 0.009154, train error 0.00,  val loss 1.617002, percent error 35.50
# Epoch    89, train loss 0.009124, train error 0.00,  val loss 1.617258, percent error 35.50
# Epoch    90, train loss 0.009093, train error 0.00,  val loss 1.618176, percent error 35.50
# Epoch    91, train loss 0.009063, train error 0.00,  val loss 1.618775, percent error 35.50
# Epoch    92, train loss 0.009032, train error 0.00,  val loss 1.619631, percent error 35.60
# Epoch    93, train loss 0.009003, train error 0.00,  val loss 1.620703, percent error 35.50
# Epoch    94, train loss 0.008973, train error 0.00,  val loss 1.621139, percent error 35.50
# Epoch    95, train loss 0.008943, train error 0.00,  val loss 1.622239, percent error 35.50
# Epoch    96, train loss 0.008913, train error 0.00,  val loss 1.622929, percent error 35.50
# Epoch    97, train loss 0.008884, train error 0.00,  val loss 1.623284, percent error 35.50
# Epoch    98, train loss 0.008855, train error 0.00,  val loss 1.624407, percent error 35.50
# Epoch    99, train loss 0.008826, train error 0.00,  val loss 1.625261, percent error 35.50
